# %% [markdown]
# # Build
# ---
# This notebook builds Cirrus. It is mainly intended for use by Cirrus developers to push a new version of the software.

# %% [markdown]
# ## Setup
# ---

# %%
# To ease development, each time a cell is run, all modules will be reloaded.
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import sys
import atexit
import subprocess

# %%
# Cirrus produces logs. Here we enable printing them in the notebook
from cirrus import utilities
utilities.set_logging_handler()
# Out:
# [     _initialize | ResourceManager] Initializing no-retries Lambda client.
# [     _initialize | ResourceManager] Initializing IAM resource.
# [     _initialize | ResourceManager] Initializing EC2 resource.
# [     _initialize | ResourceManager] Initializing Cloudwatch Logs client.
# [     _initialize | ResourceManager] Initializing S3 resource.
# [     _initialize | ResourceManager] Initializing STS client.

# %%
from cirrus import automate
from cirrus import setup

# %% [markdown]
# ## Ubuntu (parameter server)
# ---
# Cirrus parameter server is optimized for Ubuntu. In this section we create an executable for the parameter server.

# %% [markdown]
# ### Build image
# First, we create a "build image", which is an AMI on which we've set up the proper environment for building Cirrus. Making the build image is separated from making the executables because the build image will rarely need to be remade, whereas the executables will need to be remade for each new version of the system.

# %%
automate.make_ubuntu_build_image("cirrus_ubuntu_build_image")
# Out:
# [make_ubuntu_build_image |      MainThread] Deleting any existing images with the same name.
# [   delete_images |      MainThread] Describing images.
# [   delete_images |      MainThread] Done.
# [make_ubuntu_build_image |      MainThread] Launching an instance.
# [        __init__ |      MainThread] Done.
# [         _exists |      MainThread] Listing instances.
# [         _exists |      MainThread] No existing instance with the same name was found.
# [ _start_and_wait |      MainThread] Starting a new instance.
# [ _start_and_wait |      MainThread] Waiting for instance to enter running state.
# [ _start_and_wait |      MainThread] Fetching instance metadata.
# [ _start_and_wait |      MainThread] Done.
# [           start |      MainThread] Done.
# [make_ubuntu_build_image |      MainThread] Setting up the environment.
# [     run_command |      MainThread] Calling _connect_ssh.
# [    _connect_ssh |      MainThread] Configuring.
# [    _connect_ssh |      MainThread] Making connection attempt #1 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #2 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #3 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #4 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #5 out of 35.
# [     run_command |      MainThread] Running `sudo apt-get update`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 2084.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo apt-get install build-essential cmake                           automake zlib1g-dev libssl-dev libcurl4-nss-dev                           bison libldap2-dev libkrb5-dev`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 32470.
# [     run_command |      MainThread] stderr had length 401.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo apt-get install awscli`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 12013.
# [     run_command |      MainThread] stderr had length 401.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo apt-get install gdb`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 2833.
# [     run_command |      MainThread] stderr had length 401.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo apt-get install htop`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 193.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo apt-get install mosh`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 1893.
# [     run_command |      MainThread] stderr had length 401.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [make_ubuntu_build_image |      MainThread] Saving the image.
# [      save_image |      MainThread] Stopping instance.
# [      save_image |      MainThread] Starting image creation.
# [      save_image |      MainThread] Waiting for image creation.
# [      save_image |      MainThread] Doing poll #1 out of 100.
# [      save_image |      MainThread] Doing poll #2 out of 100.
# [      save_image |      MainThread] Doing poll #3 out of 100.
# [      save_image |      MainThread] Doing poll #4 out of 100.
# [      save_image |      MainThread] Doing poll #5 out of 100.
# [      save_image |      MainThread] Doing poll #6 out of 100.
# [      save_image |      MainThread] Doing poll #7 out of 100.
# [      save_image |      MainThread] Doing poll #8 out of 100.
# [      save_image |      MainThread] Doing poll #9 out of 100.
# [      save_image |      MainThread] Doing poll #10 out of 100.
# [      save_image |      MainThread] Doing poll #11 out of 100.
# [      save_image |      MainThread] Doing poll #12 out of 100.
# [      save_image |      MainThread] Doing poll #13 out of 100.
# [      save_image |      MainThread] Doing poll #14 out of 100.
# [      save_image |      MainThread] Doing poll #15 out of 100.
# [      save_image |      MainThread] Doing poll #16 out of 100.
# [      save_image |      MainThread] Doing poll #17 out of 100.
# [      save_image |      MainThread] Doing poll #18 out of 100.
# [      save_image |      MainThread] Doing poll #19 out of 100.
# [      save_image |      MainThread] Doing poll #20 out of 100.
# [      save_image |      MainThread] Doing poll #21 out of 100.
# [      save_image |      MainThread] Doing poll #22 out of 100.
# [      save_image |      MainThread] Doing poll #23 out of 100.
# [      save_image |      MainThread] Doing poll #24 out of 100.
# [      save_image |      MainThread] Doing poll #25 out of 100.
# [      save_image |      MainThread] Doing poll #26 out of 100.
# [      save_image |      MainThread] Doing poll #27 out of 100.
# [      save_image |      MainThread] Doing poll #28 out of 100.
# [      save_image |      MainThread] Doing poll #29 out of 100.
# [      save_image |      MainThread] Doing poll #30 out of 100.
# [      save_image |      MainThread] Doing poll #31 out of 100.
# [      save_image |      MainThread] Doing poll #32 out of 100.
# [      save_image |      MainThread] Doing poll #33 out of 100.
# [      save_image |      MainThread] Doing poll #34 out of 100.
# [      save_image |      MainThread] Done.
# [make_ubuntu_build_image |      MainThread] Terminating the instance.
# [         cleanup |      MainThread] Closing SSH client.
# [         cleanup |      MainThread] Terminating instance.
# [         cleanup |      MainThread] Waiting for instance to terminate.
# [         cleanup |      MainThread] Done.

# %% [markdown]
# ### Executables
# Second, we compile the Cirrus parameter server (using the build image) and publish its executables.
#
# The executables are published to the `cirrus-public` S3 bucket.

# %%
automate.make_executables(
    setup.PUBLISHED_BUILD + "/executables/ubuntu",
    ("self", "cirrus_ubuntu_build_image"),
    "ubuntu"
)
# Out:
# [make_executables |      MainThread] Launching an instance.
# [        __init__ |      MainThread] Resolving AMI owner/name to AMI ID.
# [        __init__ |      MainThread] Done.
# [         _exists |      MainThread] Listing instances.
# [         _exists |      MainThread] No existing instance with the same name was found.
# [ _start_and_wait |      MainThread] Starting a new instance.
# [ _start_and_wait |      MainThread] Waiting for instance to enter running state.
# [ _start_and_wait |      MainThread] Fetching instance metadata.
# [ _start_and_wait |      MainThread] Done.
# [           start |      MainThread] Done.
# [make_executables |      MainThread] Building Cirrus.
# [     run_command |      MainThread] Calling _connect_ssh.
# [    _connect_ssh |      MainThread] Configuring.
# [    _connect_ssh |      MainThread] Making connection attempt #1 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #2 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #3 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #4 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #5 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #6 out of 35.
# [     run_command |      MainThread] Running `git clone https://github.com/yangryan0/cirrus-1.git --branch cross_validation --single-branch cirrus`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 25.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd cirrus; ./bootstrap.sh`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 866625.
# [     run_command |      MainThread] stderr had length 89533.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd cirrus; make -j 16`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 124931.
# [     run_command |      MainThread] stderr had length 150673.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [make_executables |      MainThread] Publishing executables.
# [     run_command |      MainThread] Running `aws s3 cp ~/cirrus/src/parameter_server s3://cirrus-public-ryan1/executables/ubuntu/parameter_server --acl public-read`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 10300.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `aws s3 cp ~/cirrus/src/ps_test s3://cirrus-public-ryan1/executables/ubuntu/ps_test --acl public-read`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 10146.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `aws s3 cp ~/cirrus/src/csv_to_libsvm s3://cirrus-public-ryan1/executables/ubuntu/csv_to_libsvm --acl public-read`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 10158.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [make_executables |      MainThread] Terminating the instance.
# [         cleanup |      MainThread] Closing SSH client.
# [         cleanup |      MainThread] Terminating instance.
# [         cleanup |      MainThread] Waiting for instance to terminate.
# [         cleanup |      MainThread] Done.
# [make_executables |      MainThread] Done.

# %% [markdown]
# ## Amazon Linux (Lambdas)
# ---
# AWS Lambdas run on an Amazon Linux image. Here we build the Cirrus binaries that runs on those AWS Lambdas.

# %% [markdown]
# ### Build image
# Here we create an image used to compile the Cirrus workers executables.

# %%
automate.make_amazon_build_image("cirrus_amazon_build_image")
# Out:
# [make_amazon_build_image |      MainThread] Deleting any existing images with the same name.
# [   delete_images |      MainThread] Describing images.
# [   delete_images |      MainThread] Done.
# [make_amazon_build_image |      MainThread] Launching an instance.
# [        __init__ |      MainThread] Done.
# [         _exists |      MainThread] Listing instances.
# [         _exists |      MainThread] No existing instance with the same name was found.
# [ _start_and_wait |      MainThread] Starting a new instance.
# [ _start_and_wait |      MainThread] Waiting for instance to enter running state.
# [ _start_and_wait |      MainThread] Fetching instance metadata.
# [ _start_and_wait |      MainThread] Done.
# [           start |      MainThread] Done.
# [make_amazon_build_image |      MainThread] Setting up the environment.
# [     run_command |      MainThread] Calling _connect_ssh.
# [    _connect_ssh |      MainThread] Configuring.
# [    _connect_ssh |      MainThread] Making connection attempt #1 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #2 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #3 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #4 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt timed out after 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #5 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #6 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #7 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #8 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #9 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #10 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #11 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #12 out of 35.
# [    _connect_ssh |      MainThread] Connection attempt failed. Sleeping for 3s.
# [    _connect_ssh |      MainThread] Making connection attempt #13 out of 35.
# [     run_command |      MainThread] Running `yes | sudo yum install git glibc-static openssl-static.x86_64 zlib-static.x86_64 libcurl-devel`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 16855.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum groupinstall "Development Tools"`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 39648.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum install gdb`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 144.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum install htop`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 1139.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum install mosh`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 1890.
# [     run_command |      MainThread] stderr had length 292.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum remove gcc48-c++`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 1687.
# [     run_command |      MainThread] stderr had length 294.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum install gcc72-c++`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 1916.
# [     run_command |      MainThread] stderr had length 294.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `wget https://cmake.org/files/v3.10/cmake-3.10.0.tar.gz`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 12042.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `tar -xvzf cmake-3.10.0.tar.gz`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 712713.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd cmake-3.10.0; ./bootstrap`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 134016.
# [     run_command |      MainThread] stderr had length 73.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd cmake-3.10.0; make -j 16`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 76405.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd cmake-3.10.0; sudo make install`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 186048.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `yes | sudo yum install binutils`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 1359.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `wget https://ftp.gnu.org/gnu/make/make-4.2.tar.gz`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 3388.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `tar -xf make-4.2.tar.gz`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd make-4.2; ./configure`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 7843.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd make-4.2; make -j 16`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 8313.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd make-4.2; sudo make install`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 4028.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `sudo ln -sf /usr/local/bin/make /usr/bin/make`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `git clone git://sourceware.org/git/glibc.git`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 24.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd glibc; git checkout release/2.28/master`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 90.
# [     run_command |      MainThread] stderr had length 47.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `mkdir glibc/build`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 0.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd glibc/build; ../configure --disable-sanity-checks --enable-static-nss --prefix ~/glibc_build`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# [     run_command |      MainThread] stdout had length 5292.
# [     run_command |      MainThread] stderr had length 0.
# [     run_command |      MainThread] Exit code was 0.
# [     run_command |      MainThread] Done.
# [     run_command |      MainThread] Running `cd glibc/build; make -j 16`.
# [     run_command |      MainThread] Waiting for completion.
# [     run_command |      MainThread] Fetching stdout and stderr.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-50172dc8a978> in <module>()
# ----> 1 automate.make_amazon_build_image("cirrus_amazon_build_image")
#
# /home/ryan/Documents/cirrus_cv/python/frontend/cirrus/cirrus/automate.pyc in make_amazon_build_image(name)
#     175     instance.run_command("cd glibc/build; ../configure --disable-sanity-checks "
#     176                          "--enable-static-nss --prefix ~/glibc_build")
# --> 177     instance.run_command("cd glibc/build; make -j 16")
#     178     instance.run_command("cd glibc/build; make install")
#     179     instance.run_command("sudo cp ~/glibc_build/lib/libpthread.a "
#
# /home/ryan/Documents/cirrus_cv/python/frontend/cirrus/cirrus/instance.pyc in run_command(self, command, check)
#     431
#     432         self._log.debug("Fetching stdout and stderr.")
# --> 433         stdout_data, stderr_data = stdout.read(), stderr.read()
#     434         self._log.debug("stdout had length %d." % len(stdout_data))
#     435         self._log.debug("stderr had length %d." % len(stderr_data))
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/paramiko/file.pyc in read(self, size)
#     198             while True:
#     199                 try:
# --> 200                     new_data = self._read(self._DEFAULT_BUFSIZE)
#     201                 except EOFError:
#     202                     new_data = None
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/paramiko/channel.pyc in _read(self, size)
#    1341
#    1342     def _read(self, size):
# -> 1343         return self.channel.recv(size)
#    1344
#    1345     def _write(self, data):
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/paramiko/channel.pyc in recv(self, nbytes)
#     697         """
#     698         try:
# --> 699             out = self.in_buffer.read(nbytes, self.timeout)
#     700         except PipeTimeout:
#     701             raise socket.timeout()
#
# /home/ryan/anaconda2/lib/python2.7/site-packages/paramiko/buffered_pipe.pyc in read(self, nbytes, timeout)
#     158                 while (len(self._buffer) == 0) and not self._closed:
#     159                     then = time.time()
# --> 160                     self._cv.wait(timeout)
#     161                     if timeout is not None:
#     162                         timeout -= time.time() - then
#
# /home/ryan/anaconda2/lib/python2.7/threading.pyc in wait(self, timeout)
#     338         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     339             if timeout is None:
# --> 340                 waiter.acquire()
#     341                 if __debug__:
#     342                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Executables
# Here we compile the lambda workers executables.

# %%
automate.make_executables(
    setup.PUBLISHED_BUILD + "/executables/amazon",
    ("self", "cirrus_amazon_build_image"),
    "ec2-user"
)

# %% [markdown]
# # Cleanup
# ---
# If a cell errors, running this should clean up any resources that were created. After running this cell, the kernel will become unusable and need to be restarted.

# %%
atexit._run_exitfuncs()
# Out:
# [         cleanup |      MainThread] Closing SSH client.
# [         cleanup |      MainThread] Terminating instance.
# [         cleanup |      MainThread] Waiting for instance to terminate.
# [         cleanup |      MainThread] Done.
# [         cleanup |      MainThread] Done.
# [         cleanup |      MainThread] Done.
